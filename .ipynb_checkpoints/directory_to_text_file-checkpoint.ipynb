# %% [markdown]
# # training dataset

# %%
import os
for (root,dirs,files) in os.walk('./train_n/', topdown=True):
    if files:
        if 'groundtruth' in root:
            with open('C:/Users/HP/Sparsity_Invariant_CNN/train_gt.txt', 'a+') as f:   
                root = root.replace(os.sep, '/')
                for i in(files):
                    f.write(root + '/' + i)
                    f.write("\n")
                f.close()     
        else:
            with open('C:/Users/HP/Sparsity_Invariant_CNN/train_rd.txt', 'a+') as f:                
                root = root.replace(os.sep, '/')
                for i in(files):
                    f.write(root + '/' + i)
                    f.write("\n")
                f.close()

# %%
# concatenating the two text files rowise
combine =[]
gt_path = 'C:/Users/HP/Sparsity_Invariant_CNN/train_gt.txt'
rd_path = 'C:/Users/HP/Sparsity_Invariant_CNN/train_gt.txt'
train_path = 'C:/Users/HP/Sparsity_Invariant_CNN/train.txt'
with open(gt_path ) as xh:
    with open(rd_path ) as yh:
        with open(train_path,"w") as zh:
            #Read first file
            xlines = xh.readlines()
            #Read second file
            ylines = yh.readlines()
            #Combine content of both lists
            combine = list(zip(xlines,ylines))
            #Write to third file
            for i in range(len(xlines)):
                line = ylines[i].strip() + ' ' + xlines[i]
                zh.write(line)

# %% [markdown]
# # validation dataset

# %%
import os
for (root,dirs,files) in os.walk('./val_n/', topdown=True):
    if files:
        if 'groundtruth' in root:
            with open('C:/Users/HP/Sparsity_Invariant_CNN/train_gt.txt', 'a+') as f:   
                root = root.replace(os.sep, '/')
                for i in(files):
                    f.write(root + '/' + i)
                    f.write("\n")
                f.close()     
        else:
            with open('C:/Users/HP/Sparsity_Invariant_CNN/train_rd.txt', 'a+') as f:                
                root = root.replace(os.sep, '/')
                for i in(files):
                    f.write(root + '/' + i)
                    f.write("\n")
                f.close()   
# train.txt is

# %%
# concatenating the two text files rowise
combine =[]
gt_path = 'C:/Users/HP/Sparsity_Invariant_CNN/train_gt.txt'
rd_path = 'C:/Users/HP/Sparsity_Invariant_CNN/train_gt.txt'
train_path = 'C:/Users/HP/Sparsity_Invariant_CNN/val.txt'
with open(gt_path ) as xh:
    with open(rd_path ) as yh:
        with open(train_path,"w") as zh:
            #Read first file
            xlines = xh.readlines()
            #Read second file
            ylines = yh.readlines()
            #Combine content of both lists
            combine = list(zip(xlines,ylines))
            #Write to third file
            for i in range(len(xlines)):
                line = ylines[i].strip() + ' ' + xlines[i]
                zh.write(line)
# val.txt is 3536

# %% [markdown]
# # test dataset

# %%
import os
for (root,dirs,files) in os.walk('./test/', topdown=True):
    if files:
        if 'groundtruth' in root:
            with open('C:/Users/HP/Sparsity_Invariant_CNN/train_gt.txt', 'a+') as f:   
                root = root.replace(os.sep, '/')
                for i in(files):
                    f.write(root + '/' + i)
                    f.write("\n")
                f.close()     
        else:
            with open('C:/Users/HP/Sparsity_Invariant_CNN/train_rd.txt', 'a+') as f:                
                root = root.replace(os.sep, '/')
                for i in(files):
                    f.write(root + '/' + i)
                    f.write("\n")
                f.close()   
# train.txt is

# %%
# concatenating the two text files rowise
combine =[]
gt_path = 'C:/Users/HP/Sparsity_Invariant_CNN/train_gt.txt'
rd_path = 'C:/Users/HP/Sparsity_Invariant_CNN/train_gt.txt'
train_path = 'C:/Users/HP/Sparsity_Invariant_CNN/test.txt'
with open(gt_path ) as xh:
    with open(rd_path ) as yh:
        with open(train_path,"w") as zh:
            #Read first file
            xlines = xh.readlines()
            #Read second file
            ylines = yh.readlines()
            #Combine content of both lists
            combine = list(zip(xlines,ylines))
            #Write to third file
            for i in range(len(xlines)):
                line = ylines[i].strip() + ' ' + xlines[i]
                zh.write(line)
# val.txt is 3536

# %%
# Opening a file
file = open('C:/Users/HP/Sparsity_Invariant_CNN/train.txt')
Counter = 0
  
# Reading from file
Content = file.read()
CoList = Content.split("\n")
  
for i in CoList:
    if i:
        Counter += 1
          
print("This is the number of lines in the file")
print(Counter)
